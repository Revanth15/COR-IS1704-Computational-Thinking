# %%
#we define here a var called pi, this var points at a number
#in practice, a variable can be other 
#a string, list or dict

pi = 3.14

# we are using here a special function called print()
# print() takes an argument, and prints out the argument as a str
print(pi)
# Out:
# 3.14

# %% [markdown]
# # Week 1
# these are my notes for week 1 in COR-IS1704
#
# * variables
# * strings
# * numbers: floats, ints
# * reminder of PEMDAS
#
# # Topic 1: Variables

# %%
# what is the formula for area of rectangle
# rec = length * width
length= 5
width = 10
rectangle_area= length * width
print(rectangle_area)

# what is the formula for the area of circle
# circle = pi * radius squared
radius=2
circle_area = pi * (radius*radius)
print(circle_area)

# what is the formula for the valume of a sphere
sphere_volume= 4/3*pi * radius **3 
print(sphere_volume)
# Out:
# 50
# 12.56
# 33.49333333333333

# %%
# math operations
# +
# -
# *
# /
# **
# //
# % (remainder of)

#PEMDAS
#1. Parentheses
#2. Exponentiation, 
#3. Multiplication, Division
#4. Addition & Subtraction

10+5*4 #==> 30
(10+5)*(2-1) #==>15

#In python, there are 2 types of numbers: integers and floating point
# Numbers/(numbers with decimals)
#using some math operations result sin floats and other math operations
#result in integers, the thing to know is that it depends both on the operands and operation itself.

# %%
# let's get some input from the user

name=input("what is your name")
print("Hello, " + name)
# Out:
# Hello, revanth

# %%
height=input("what is your height")
height_as_a_integer=int(height) 
#it will break if we enter a decimal, so we should use float(height) instead
print(height_as_a_integer*2)

#--Version 2
#height=float(input("what is your height")) #this works too
#height_doubled= height*2
#print("Your height is," + str(height_doubled))
# Out:
# 6

# %%
#c=(f-32)*5/9
#conduxt a temp convertor 

temp=float(input("what is the tempurature in Fahrenheit"))
c=(temp-32)*5/9
print(c)
print("The tempurature in Fahrenheit is ", c)
print("The tempurature in Fahrenheit is "+ str(c) +" degree celsius") 
# u cannot concate a str with a number, u need to make it back to a string
# Out:
# 8.666666666666666
# The tempurature in Fahrenheit is  8.666666666666666
# The tempurature in Fahrenheit is 8.666666666666666 degree celsius
