# %% [markdown]
# # COR-IS1704 Computational Thinking
# ## Week 1 Fundamentals — Practice Test
#
# **Practice notebook · 5 questions · 20 marks · suggested time: 35 minutes**
#
# This source-grounded practice test checks the Python fundamentals covered in the Week 1 lesson and in-class exercise notebooks. It is practice material, not a prediction of an actual assessment.

# %% [markdown]
# ### Coverage and format
#
# | Question | Main skills | Response | Marks |
# |---|---|---|---:|
# | 1 | Variables, naming rules, data types, comments | Selection and short explanation | 4 |
# | 2 | Arithmetic operators, precedence, associativity, output tracing | Exact output and reasoning | 5 |
# | 3 | Strings, concatenation, repetition, quotes, `print()` and f-strings | Short code | 3 |
# | 4 | `input()`, type conversion, arithmetic, BMI-style application | Complete program and explanation | 4 |
# | 5 | Modulo, integer input, percentages, program construction | Complete program and explanation | 4 |
#
# **Source anchors:** `1. Fundamentals.ipynb`, Learning Outcomes (cell 2), Variables and Naming Rules (cells 3–11), Data Types (cells 12–17), Operators (cells 18–42), Built-in Functions and Conversion (cells 43–64), and Comments (cells 68–70). The assessment-style programming tasks are drawn from `1. In-Class Exercises.ipynb`, Operators (cells 2–3), BMI Calculator (cells 4–5), and Odd/Even Numbers (cells 6–8).

# %% [markdown]
# ### Instructions
#
# - Answer all five questions.
# - For Question 2, commit to your predicted output before running any equivalent code. Preserve spaces, decimal points, and line breaks.
# - For programming questions, use Python 3 and no external libraries.
# - Question 5 must not use `if`, `elif`, or `else`.
# - The response cells are templates. Replace the placeholders with your answers and run your completed code where appropriate.
# - No answer key is included in this student version.

# %% [markdown]
# ## Question 1 — Variables, names, types, and comments (4 marks)
#
# **1a (1 mark).** Choose the most appropriate valid Python variable name for the number of attempts made by a student. Record the letter and the name.
#
# A. `2nd_attempt`
# B. `number of attempts`
# C. `class`
# D. `number_of_attempts`
#
# **1b (1 mark).** Give the Python data type of each value. Use only `int`, `float`, or `str`.
#
# ```python
# count = 7
# ratio = 0.625
# module_code = "COR-IS1704"
# ```
#
# **1c (2 marks).** Explain why the final line raises a `NameError`. State the minimal change needed for it to print a weight.
#
# ```python
# my_height = 1.70
# # my_weight = 65.0
# print(my_height)
# print(my_weight)
# ```

# %%
# Question 1 response template
q1a_choice = "D, number_of_attempts"             # enter A, B, C, or D and the chosen name
q1b_count_type = "int"
q1b_ratio_type = "float"
q1b_module_code_type = "str"
q1c_explanation = "The variable is commented out which prevents the print from accessing the variable, we can uncomment the variable to get this working."       # explain the error and the minimal change

# %% [markdown]
# ## Question 2 — Arithmetic operators and evaluation order (5 marks)
#
# Without running the snippet, record its exact output. Then explain why the third line evaluates from right to left. The output portion is worth 4 marks and the explanation is worth 1 mark.
#
# ```python
# print(4 + 3 * 2 ** 2)
# print(19 // 6, 19 % 6)
# print(2 ** 3 ** 2)
# print(7 / 2)
# print("go" + "!" * 3)
# ```

# %%
# Question 2 response template — write the five output lines before running the snippet.
q2_predicted_output = """
18
3, 1
64
3.5
go!!!
"""
q2_associativity_explanation = "just math innit"

# %% [markdown]
# ## Question 3 — Strings and output formatting (3 marks)
#
# Use the variables below.
#
# ```python
# course = "COR-IS1704"
# student = "Kai Lim"
# ```
#
# **3a (1 mark).** Write one f-string `print()` statement that displays exactly:
#
# ```text
# Course: COR-IS1704 | Student: Kai Lim
# ```
#
# **3b (1 mark).** Replace the right-hand side of `label` with one valid expression that makes `print(label)` display `Batch-17`. Use `str()` or another Week 1 technique; do not change `prefix` or `number`.
#
# ```python
# prefix = "Batch-"
# number = 17
# label = ???
# print(label)
# ```
#
# **3c (1 mark).** Write one valid Python string literal whose value is exactly `She said, "Ready!"`. Choose quote marks so the inner double quotes are part of the string.

# %%
# Question 3 response template
course = "COR-IS1704"
student = "Kai Lim"

# Q3a: write your f-string print statement below.
print(f"Course: {course} | Student: {student}")

prefix = "Batch-"
number = 17
label = prefix + str(number)      # replace with your expression
print(label)

quote = 'She said, "Ready!"'       # replace with your string literal
print(quote)
# Out:
# Course: COR-IS1704 | Student: Kai Lim
# Batch-17
# She said, "Ready!"

# %% [markdown]
# ## Question 4 — `input()`, conversion, and a BMI calculation (4 marks)
#
# Write a complete program that:
#
# 1. Prompts for a person's weight in kilograms and stores the result in `weight_text`.
# 2. Prompts for height in metres and stores the result in `height_text`.
# 3. Converts both inputs to suitable numeric values and computes `BMI = weight / height ** 2`.
# 4. Displays the result with an f-string beginning with `BMI: `.
#
# The program is worth 3 marks. In one sentence, explain why the input values cannot be used directly in the arithmetic expression before conversion (1 mark).

# %%
# Question 4 response template
weight_text = input("Weight (kg): ")
height_text = input("Height (m): ")

# Convert the inputs, calculate BMI, and print it below.
BMI = int(weight_text) / float(height_text) ** 2
print(f"BMI: {BMI}")

q4_explanation = "input returns a string so we cannot just do math on it without converting it to an input or a float"  # explain the type returned by input()
# Out:
# BMI: 20.37037037037037

# %% [markdown]
# ## Question 5 — Modulo and percentage calculation (4 marks)
#
# A monitoring script receives exactly four integer readings. Write a program that:
#
# - prompts for the four readings sequentially and converts each input to an `int`;
# - counts odd readings using the modulo-2 operation;
# - derives the even count and calculates the odd and even percentages out of four; and
# - prints both percentages using f-strings.
#
# Do not use `if`, `elif`, or `else`. You may use four explicit variables, or a loop/list approach if you are comfortable with the constructs shown in the in-class exercise. Include a one-sentence explanation of why the modulo result can be used to count odd readings. The program is worth 3 marks and the explanation is worth 1 mark.

# %%
# Question 5 response template
reading_1 = int(input("Reading 1: "))
reading_2 = int(input("Reading 2: "))
reading_3 = int(input("Reading 3: "))
reading_4 = int(input("Reading 4: "))



# Complete the solution below without using if/elif/else.

q5_explanation = ""  # explain the modulo-2 idea

# %% [markdown]
# ## Submission checklist
#
# Before submitting or asking for grading, check that you have:
#
# - supplied all Question 1 responses and explained the `NameError`;
# - written Question 2's output exactly, including decimal points and spaces;
# - used a valid f-string, `str()`, and quote choice in Question 3;
# - converted both `input()` results before the BMI calculation; and
# - avoided conditional statements in Question 5 and printed both percentages.
