# %%
import greet

name = input('Enter your name :')
greet.say_hello(name)
greet.say_bye(name)
# Out:
# Hello revanth !
# Bye revanth !

# %%
import math

# prompt the user for a number
num = float(input('Enter a number :'))
# Calculate the square root of num
result = math.sqrt(num) 
# display the result
print('Square root of',num,'is :',result)

# %%
print(2 ** 3 + 1.0)
print(2 ** 2 ** 3 % 7)
print("a" + "123")
# print('3' * 'bc')
x = type(input('Enter your age:'))
print(x)
# Out:
# 9.0
# 4
# a123
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 print(2 ** 3 + 1.0)
#       2 print(2 ** 2 ** 3 % 7)
#       3 print("a" + "123")
# ----> 4 print('3' * 'bc')
#       5 x = type(input('Enter your age:'))
#       6 print(x)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
def greet():
      get_name()
      print('Hi!', names)

def get_name():
        names = input('Enter your name: ')
        print('Hi!', names)
greet()
# Out:
# Hi! rev
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 8
#       4
#       5 def get_name():
#       6         names = input('Enter your name: ')
#       7         print('Hi!', names)
# ----> 8 greet()
#
# Cell In[15], line 3, in greet()
#       1 def greet():
#       2       get_name()
# ----> 3       print('Hi!', names)
#
# NameError: name 'names' is not defined
